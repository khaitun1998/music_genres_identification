# %%
import sounddevice as sd
import soundfile as sf
from IPython.display import Audio
import numpy as np
import librosa
import hmmlearn.hmm as hmm

# %%
def record_sound(duration, filename=None, fs=44100):
    sd.play(5.0*np.sin(2*np.pi*940*np.arange(fs)/fs), samplerate=fs, blocking = True)
    sd.play(0.0*np.sin(2*np.pi*940*np.arange(fs*0.3)/fs), samplerate=fs, blocking = True)
    data = sd.rec(int(duration * fs), samplerate=fs, channels = 1, blocking = True)
    print("Recording")
    sd.wait()
    print("Done recording")
    
    if filename is not None:
        sf.write(filename, data, samplerate=fs)
    return data.T, fs

# %%
def get_mfcc(filename):
    data, fs = librosa.load(filename, sr=None)
    mfcc = librosa.feature.mfcc(data, fs);
    return mfcc

# %%
all_mfcc_blues = []
for i in range(100):
    print('Processing genres/blues/blues.{}.au'.format(i+1))
    mfcc = get_mfcc('genres/blues/blues.{}.au'.format(i+1))
    all_mfcc_blues.append(mfcc)
# Out:
# Processing genres/blues/blues.1.au
# Processing genres/blues/blues.2.au
# Processing genres/blues/blues.3.au
# Processing genres/blues/blues.4.au
# Processing genres/blues/blues.5.au
# Processing genres/blues/blues.6.au
# Processing genres/blues/blues.7.au
# Processing genres/blues/blues.8.au
# Processing genres/blues/blues.9.au
# Processing genres/blues/blues.10.au
# Processing genres/blues/blues.11.au
# Processing genres/blues/blues.12.au
# Processing genres/blues/blues.13.au
# Processing genres/blues/blues.14.au
# Processing genres/blues/blues.15.au
# Processing genres/blues/blues.16.au
# Processing genres/blues/blues.17.au
# Processing genres/blues/blues.18.au
# Processing genres/blues/blues.19.au
# Processing genres/blues/blues.20.au
# Processing genres/blues/blues.21.au
# Processing genres/blues/blues.22.au
# Processing genres/blues/blues.23.au
# Processing genres/blues/blues.24.au
# Processing genres/blues/blues.25.au
# Processing genres/blues/blues.26.au
# Processing genres/blues/blues.27.au
# Processing genres/blues/blues.28.au
# Processing genres/blues/blues.29.au
# Processing genres/blues/blues.30.au
# Processing genres/blues/blues.31.au
# Processing genres/blues/blues.32.au
# Processing genres/blues/blues.33.au
# Processing genres/blues/blues.34.au
# Processing genres/blues/blues.35.au
# Processing genres/blues/blues.36.au
# Processing genres/blues/blues.37.au
# Processing genres/blues/blues.38.au
# Processing genres/blues/blues.39.au
# Processing genres/blues/blues.40.au
# Processing genres/blues/blues.41.au
# Processing genres/blues/blues.42.au
# Processing genres/blues/blues.43.au
# Processing genres/blues/blues.44.au
# Processing genres/blues/blues.45.au
# Processing genres/blues/blues.46.au
# Processing genres/blues/blues.47.au
# Processing genres/blues/blues.48.au
# Processing genres/blues/blues.49.au
# Processing genres/blues/blues.50.au
# Processing genres/blues/blues.51.au
# Processing genres/blues/blues.52.au
# Processing genres/blues/blues.53.au
# Processing genres/blues/blues.54.au
# Processing genres/blues/blues.55.au
# Processing genres/blues/blues.56.au
# Processing genres/blues/blues.57.au
# Processing genres/blues/blues.58.au
# Processing genres/blues/blues.59.au
# Processing genres/blues/blues.60.au
# Processing genres/blues/blues.61.au
# Processing genres/blues/blues.62.au
# Processing genres/blues/blues.63.au
# Processing genres/blues/blues.64.au
# Processing genres/blues/blues.65.au
# Processing genres/blues/blues.66.au
# Processing genres/blues/blues.67.au
# Processing genres/blues/blues.68.au
# Processing genres/blues/blues.69.au
# Processing genres/blues/blues.70.au
# Processing genres/blues/blues.71.au
# Processing genres/blues/blues.72.au
# Processing genres/blues/blues.73.au
# Processing genres/blues/blues.74.au
# Processing genres/blues/blues.75.au
# Processing genres/blues/blues.76.au
# Processing genres/blues/blues.77.au
# Processing genres/blues/blues.78.au
# Processing genres/blues/blues.79.au
# Processing genres/blues/blues.80.au
# Processing genres/blues/blues.81.au
# Processing genres/blues/blues.82.au
# Processing genres/blues/blues.83.au
# Processing genres/blues/blues.84.au
# Processing genres/blues/blues.85.au
# Processing genres/blues/blues.86.au
# Processing genres/blues/blues.87.au
# Processing genres/blues/blues.88.au
# Processing genres/blues/blues.89.au
# Processing genres/blues/blues.90.au
# Processing genres/blues/blues.91.au
# Processing genres/blues/blues.92.au
# Processing genres/blues/blues.93.au
# Processing genres/blues/blues.94.au
# Processing genres/blues/blues.95.au
# Processing genres/blues/blues.96.au
# Processing genres/blues/blues.97.au
# Processing genres/blues/blues.98.au
# Processing genres/blues/blues.99.au
# Processing genres/blues/blues.100.au

# %%
all_mfcc_classical = []
for i in range(100):
    print('Processing genres/classical/classical.{}.au'.format(i+1))
    mfcc = get_mfcc('genres/classical/classical.{}.au'.format(i+1))
    all_mfcc_classical.append(mfcc)
# Out:
# Processing genres/classical/classical.1.au
# Processing genres/classical/classical.2.au
# Processing genres/classical/classical.3.au
# Processing genres/classical/classical.4.au
# Processing genres/classical/classical.5.au
# Processing genres/classical/classical.6.au
# Processing genres/classical/classical.7.au
# Processing genres/classical/classical.8.au
# Processing genres/classical/classical.9.au
# Processing genres/classical/classical.10.au
# Processing genres/classical/classical.11.au
# Processing genres/classical/classical.12.au
# Processing genres/classical/classical.13.au
# Processing genres/classical/classical.14.au
# Processing genres/classical/classical.15.au
# Processing genres/classical/classical.16.au
# Processing genres/classical/classical.17.au
# Processing genres/classical/classical.18.au
# Processing genres/classical/classical.19.au
# Processing genres/classical/classical.20.au
# Processing genres/classical/classical.21.au
# Processing genres/classical/classical.22.au
# Processing genres/classical/classical.23.au
# Processing genres/classical/classical.24.au
# Processing genres/classical/classical.25.au
# Processing genres/classical/classical.26.au
# Processing genres/classical/classical.27.au
# Processing genres/classical/classical.28.au
# Processing genres/classical/classical.29.au
# Processing genres/classical/classical.30.au
# Processing genres/classical/classical.31.au
# Processing genres/classical/classical.32.au
# Processing genres/classical/classical.33.au
# Processing genres/classical/classical.34.au
# Processing genres/classical/classical.35.au
# Processing genres/classical/classical.36.au
# Processing genres/classical/classical.37.au
# Processing genres/classical/classical.38.au
# Processing genres/classical/classical.39.au
# Processing genres/classical/classical.40.au
# Processing genres/classical/classical.41.au
# Processing genres/classical/classical.42.au
# Processing genres/classical/classical.43.au
# Processing genres/classical/classical.44.au
# Processing genres/classical/classical.45.au
# Processing genres/classical/classical.46.au
# Processing genres/classical/classical.47.au
# Processing genres/classical/classical.48.au
# Processing genres/classical/classical.49.au
# Processing genres/classical/classical.50.au
# Processing genres/classical/classical.51.au
# Processing genres/classical/classical.52.au
# Processing genres/classical/classical.53.au
# Processing genres/classical/classical.54.au
# Processing genres/classical/classical.55.au
# Processing genres/classical/classical.56.au
# Processing genres/classical/classical.57.au
# Processing genres/classical/classical.58.au
# Processing genres/classical/classical.59.au
# Processing genres/classical/classical.60.au
# Processing genres/classical/classical.61.au
# Processing genres/classical/classical.62.au
# Processing genres/classical/classical.63.au
# Processing genres/classical/classical.64.au
# Processing genres/classical/classical.65.au
# Processing genres/classical/classical.66.au
# Processing genres/classical/classical.67.au
# Processing genres/classical/classical.68.au
# Processing genres/classical/classical.69.au
# Processing genres/classical/classical.70.au
# Processing genres/classical/classical.71.au
# Processing genres/classical/classical.72.au
# Processing genres/classical/classical.73.au
# Processing genres/classical/classical.74.au
# Processing genres/classical/classical.75.au
# Processing genres/classical/classical.76.au
# Processing genres/classical/classical.77.au
# Processing genres/classical/classical.78.au
# Processing genres/classical/classical.79.au
# Processing genres/classical/classical.80.au
# Processing genres/classical/classical.81.au
# Processing genres/classical/classical.82.au
# Processing genres/classical/classical.83.au
# Processing genres/classical/classical.84.au
# Processing genres/classical/classical.85.au
# Processing genres/classical/classical.86.au
# Processing genres/classical/classical.87.au
# Processing genres/classical/classical.88.au
# Processing genres/classical/classical.89.au
# Processing genres/classical/classical.90.au
# Processing genres/classical/classical.91.au
# Processing genres/classical/classical.92.au
# Processing genres/classical/classical.93.au
# Processing genres/classical/classical.94.au
# Processing genres/classical/classical.95.au
# Processing genres/classical/classical.96.au
# Processing genres/classical/classical.97.au
# Processing genres/classical/classical.98.au
# Processing genres/classical/classical.99.au
# Processing genres/classical/classical.100.au

# %%
all_mfcc_country = []
for i in range(100):
    print('Processing genres/country/country.{}.au'.format(i+1))
    mfcc = get_mfcc('genres/country/country.{}.au'.format(i+1))
    all_mfcc_country.append(mfcc)
# Out:
# Processing genres/country/country.1.au
# Processing genres/country/country.2.au
# Processing genres/country/country.3.au
# Processing genres/country/country.4.au
# Processing genres/country/country.5.au
# Processing genres/country/country.6.au
# Processing genres/country/country.7.au
# Processing genres/country/country.8.au
# Processing genres/country/country.9.au
# Processing genres/country/country.10.au
# Processing genres/country/country.11.au
# Processing genres/country/country.12.au
# Processing genres/country/country.13.au
# Processing genres/country/country.14.au
# Processing genres/country/country.15.au
# Processing genres/country/country.16.au
# Processing genres/country/country.17.au
# Processing genres/country/country.18.au
# Processing genres/country/country.19.au
# Processing genres/country/country.20.au
# Processing genres/country/country.21.au
# Processing genres/country/country.22.au
# Processing genres/country/country.23.au
# Processing genres/country/country.24.au
# Processing genres/country/country.25.au
# Processing genres/country/country.26.au
# Processing genres/country/country.27.au
# Processing genres/country/country.28.au
# Processing genres/country/country.29.au
# Processing genres/country/country.30.au
# Processing genres/country/country.31.au
# Processing genres/country/country.32.au
# Processing genres/country/country.33.au
# Processing genres/country/country.34.au
# Processing genres/country/country.35.au
# Processing genres/country/country.36.au
# Processing genres/country/country.37.au
# Processing genres/country/country.38.au
# Processing genres/country/country.39.au
# Processing genres/country/country.40.au
# Processing genres/country/country.41.au
# Processing genres/country/country.42.au
# Processing genres/country/country.43.au
# Processing genres/country/country.44.au
# Processing genres/country/country.45.au
# Processing genres/country/country.46.au
# Processing genres/country/country.47.au
# Processing genres/country/country.48.au
# Processing genres/country/country.49.au
# Processing genres/country/country.50.au
# Processing genres/country/country.51.au
# Processing genres/country/country.52.au
# Processing genres/country/country.53.au
# Processing genres/country/country.54.au
# Processing genres/country/country.55.au
# Processing genres/country/country.56.au
# Processing genres/country/country.57.au
# Processing genres/country/country.58.au
# Processing genres/country/country.59.au
# Processing genres/country/country.60.au
# Processing genres/country/country.61.au
# Processing genres/country/country.62.au
# Processing genres/country/country.63.au
# Processing genres/country/country.64.au
# Processing genres/country/country.65.au
# Processing genres/country/country.66.au
# Processing genres/country/country.67.au
# Processing genres/country/country.68.au
# Processing genres/country/country.69.au
# Processing genres/country/country.70.au
# Processing genres/country/country.71.au
# Processing genres/country/country.72.au
# Processing genres/country/country.73.au
# Processing genres/country/country.74.au
# Processing genres/country/country.75.au
# Processing genres/country/country.76.au
# Processing genres/country/country.77.au
# Processing genres/country/country.78.au
# Processing genres/country/country.79.au
# Processing genres/country/country.80.au
# Processing genres/country/country.81.au
# Processing genres/country/country.82.au
# Processing genres/country/country.83.au
# Processing genres/country/country.84.au
# Processing genres/country/country.85.au
# Processing genres/country/country.86.au
# Processing genres/country/country.87.au
# Processing genres/country/country.88.au
# Processing genres/country/country.89.au
# Processing genres/country/country.90.au
# Processing genres/country/country.91.au
# Processing genres/country/country.92.au
# Processing genres/country/country.93.au
# Processing genres/country/country.94.au
# Processing genres/country/country.95.au
# Processing genres/country/country.96.au
# Processing genres/country/country.97.au
# Processing genres/country/country.98.au
# Processing genres/country/country.99.au
# Processing genres/country/country.100.au

# %%
all_mfcc_disco = []
for i in range(100):
    print('Processing genres/disco/disco.{}.au'.format(i+1))
    mfcc = get_mfcc('genres/disco/disco.{}.au'.format(i+1))
    all_mfcc_disco.append(mfcc)
# Out:
# Processing genres/disco/disco.1.au
# Processing genres/disco/disco.2.au
# Processing genres/disco/disco.3.au
# Processing genres/disco/disco.4.au
# Processing genres/disco/disco.5.au
# Processing genres/disco/disco.6.au
# Processing genres/disco/disco.7.au
# Processing genres/disco/disco.8.au
# Processing genres/disco/disco.9.au
# Processing genres/disco/disco.10.au
# Processing genres/disco/disco.11.au
# Processing genres/disco/disco.12.au
# Processing genres/disco/disco.13.au
# Processing genres/disco/disco.14.au
# Processing genres/disco/disco.15.au
# Processing genres/disco/disco.16.au
# Processing genres/disco/disco.17.au
# Processing genres/disco/disco.18.au
# Processing genres/disco/disco.19.au
# Processing genres/disco/disco.20.au
# Processing genres/disco/disco.21.au
# Processing genres/disco/disco.22.au
# Processing genres/disco/disco.23.au
# Processing genres/disco/disco.24.au
# Processing genres/disco/disco.25.au
# Processing genres/disco/disco.26.au
# Processing genres/disco/disco.27.au
# Processing genres/disco/disco.28.au
# Processing genres/disco/disco.29.au
# Processing genres/disco/disco.30.au
# Processing genres/disco/disco.31.au
# Processing genres/disco/disco.32.au
# Processing genres/disco/disco.33.au
# Processing genres/disco/disco.34.au
# Processing genres/disco/disco.35.au
# Processing genres/disco/disco.36.au
# Processing genres/disco/disco.37.au
# Processing genres/disco/disco.38.au
# Processing genres/disco/disco.39.au
# Processing genres/disco/disco.40.au
# Processing genres/disco/disco.41.au
# Processing genres/disco/disco.42.au
# Processing genres/disco/disco.43.au
# Processing genres/disco/disco.44.au
# Processing genres/disco/disco.45.au
# Processing genres/disco/disco.46.au
# Processing genres/disco/disco.47.au
# Processing genres/disco/disco.48.au
# Processing genres/disco/disco.49.au
# Processing genres/disco/disco.50.au
# Processing genres/disco/disco.51.au
# Processing genres/disco/disco.52.au
# Processing genres/disco/disco.53.au
# Processing genres/disco/disco.54.au
# Processing genres/disco/disco.55.au
# Processing genres/disco/disco.56.au
# Processing genres/disco/disco.57.au
# Processing genres/disco/disco.58.au
# Processing genres/disco/disco.59.au
# Processing genres/disco/disco.60.au
# Processing genres/disco/disco.61.au
# Processing genres/disco/disco.62.au
# Processing genres/disco/disco.63.au
# Processing genres/disco/disco.64.au
# Processing genres/disco/disco.65.au
# Processing genres/disco/disco.66.au
# Processing genres/disco/disco.67.au
# Processing genres/disco/disco.68.au
# Processing genres/disco/disco.69.au
# Processing genres/disco/disco.70.au
# Processing genres/disco/disco.71.au
# Processing genres/disco/disco.72.au
# Processing genres/disco/disco.73.au
# Processing genres/disco/disco.74.au
# Processing genres/disco/disco.75.au
# Processing genres/disco/disco.76.au
# Processing genres/disco/disco.77.au
# Processing genres/disco/disco.78.au
# Processing genres/disco/disco.79.au
# Processing genres/disco/disco.80.au
# Processing genres/disco/disco.81.au
# Processing genres/disco/disco.82.au
# Processing genres/disco/disco.83.au
# Processing genres/disco/disco.84.au
# Processing genres/disco/disco.85.au
# Processing genres/disco/disco.86.au
# Processing genres/disco/disco.87.au
# Processing genres/disco/disco.88.au
# Processing genres/disco/disco.89.au
# Processing genres/disco/disco.90.au
# Processing genres/disco/disco.91.au
# Processing genres/disco/disco.92.au
# Processing genres/disco/disco.93.au
# Processing genres/disco/disco.94.au
# Processing genres/disco/disco.95.au
# Processing genres/disco/disco.96.au
# Processing genres/disco/disco.97.au
# Processing genres/disco/disco.98.au
# Processing genres/disco/disco.99.au
# Processing genres/disco/disco.100.au

# %%
all_mfcc_hiphop = []
for i in range(100):
    print('Processing genres/hiphop/hiphop.{}.au'.format(i+1))
    mfcc = get_mfcc('genres/hiphop/hiphop.{}.au'.format(i+1))
    all_mfcc_hiphop.append(mfcc)
# Out:
# Processing genres/hiphop/hiphop.1.au
# Processing genres/hiphop/hiphop.2.au
# Processing genres/hiphop/hiphop.3.au
# Processing genres/hiphop/hiphop.4.au
# Processing genres/hiphop/hiphop.5.au
# Processing genres/hiphop/hiphop.6.au
# Processing genres/hiphop/hiphop.7.au
# Processing genres/hiphop/hiphop.8.au
# Processing genres/hiphop/hiphop.9.au
# Processing genres/hiphop/hiphop.10.au
# Processing genres/hiphop/hiphop.11.au
# Processing genres/hiphop/hiphop.12.au
# Processing genres/hiphop/hiphop.13.au
# Processing genres/hiphop/hiphop.14.au
# Processing genres/hiphop/hiphop.15.au
# Processing genres/hiphop/hiphop.16.au
# Processing genres/hiphop/hiphop.17.au
# Processing genres/hiphop/hiphop.18.au
# Processing genres/hiphop/hiphop.19.au
# Processing genres/hiphop/hiphop.20.au
# Processing genres/hiphop/hiphop.21.au
# Processing genres/hiphop/hiphop.22.au
# Processing genres/hiphop/hiphop.23.au
# Processing genres/hiphop/hiphop.24.au
# Processing genres/hiphop/hiphop.25.au
# Processing genres/hiphop/hiphop.26.au
# Processing genres/hiphop/hiphop.27.au
# Processing genres/hiphop/hiphop.28.au
# Processing genres/hiphop/hiphop.29.au
# Processing genres/hiphop/hiphop.30.au
# Processing genres/hiphop/hiphop.31.au
# Processing genres/hiphop/hiphop.32.au
# Processing genres/hiphop/hiphop.33.au
# Processing genres/hiphop/hiphop.34.au
# Processing genres/hiphop/hiphop.35.au
# Processing genres/hiphop/hiphop.36.au
# Processing genres/hiphop/hiphop.37.au
# Processing genres/hiphop/hiphop.38.au
# Processing genres/hiphop/hiphop.39.au
# Processing genres/hiphop/hiphop.40.au
# Processing genres/hiphop/hiphop.41.au
# Processing genres/hiphop/hiphop.42.au
# Processing genres/hiphop/hiphop.43.au
# Processing genres/hiphop/hiphop.44.au
# Processing genres/hiphop/hiphop.45.au
# Processing genres/hiphop/hiphop.46.au
# Processing genres/hiphop/hiphop.47.au
# Processing genres/hiphop/hiphop.48.au
# Processing genres/hiphop/hiphop.49.au
# Processing genres/hiphop/hiphop.50.au
# Processing genres/hiphop/hiphop.51.au
# Processing genres/hiphop/hiphop.52.au
# Processing genres/hiphop/hiphop.53.au
# Processing genres/hiphop/hiphop.54.au
# Processing genres/hiphop/hiphop.55.au
# Processing genres/hiphop/hiphop.56.au
# Processing genres/hiphop/hiphop.57.au
# Processing genres/hiphop/hiphop.58.au
# Processing genres/hiphop/hiphop.59.au
# Processing genres/hiphop/hiphop.60.au
# Processing genres/hiphop/hiphop.61.au
# Processing genres/hiphop/hiphop.62.au
# Processing genres/hiphop/hiphop.63.au
# Processing genres/hiphop/hiphop.64.au
# Processing genres/hiphop/hiphop.65.au
# Processing genres/hiphop/hiphop.66.au
# Processing genres/hiphop/hiphop.67.au
# Processing genres/hiphop/hiphop.68.au
# Processing genres/hiphop/hiphop.69.au
# Processing genres/hiphop/hiphop.70.au
# Processing genres/hiphop/hiphop.71.au
# Processing genres/hiphop/hiphop.72.au
# Processing genres/hiphop/hiphop.73.au
# Processing genres/hiphop/hiphop.74.au
# Processing genres/hiphop/hiphop.75.au
# Processing genres/hiphop/hiphop.76.au
# Processing genres/hiphop/hiphop.77.au
# Processing genres/hiphop/hiphop.78.au
# Processing genres/hiphop/hiphop.79.au
# Processing genres/hiphop/hiphop.80.au
# Processing genres/hiphop/hiphop.81.au
# Processing genres/hiphop/hiphop.82.au
# Processing genres/hiphop/hiphop.83.au
# Processing genres/hiphop/hiphop.84.au
# Processing genres/hiphop/hiphop.85.au
# Processing genres/hiphop/hiphop.86.au
# Processing genres/hiphop/hiphop.87.au
# Processing genres/hiphop/hiphop.88.au
# Processing genres/hiphop/hiphop.89.au
# Processing genres/hiphop/hiphop.90.au
# Processing genres/hiphop/hiphop.91.au
# Processing genres/hiphop/hiphop.92.au
# Processing genres/hiphop/hiphop.93.au
# Processing genres/hiphop/hiphop.94.au
# Processing genres/hiphop/hiphop.95.au
# Processing genres/hiphop/hiphop.96.au
# Processing genres/hiphop/hiphop.97.au
# Processing genres/hiphop/hiphop.98.au
# Processing genres/hiphop/hiphop.99.au
# Processing genres/hiphop/hiphop.100.au

# %%
all_mfcc_jazz = []
for i in range(100):
    print('Processing genres/jazz/jazz.{}.au'.format(i+1))
    mfcc = get_mfcc('genres/jazz/jazz.{}.au'.format(i+1))
    all_mfcc_jazz.append(mfcc)
# Out:
# Processing genres/jazz/jazz.1.au
# Processing genres/jazz/jazz.2.au
# Processing genres/jazz/jazz.3.au
# Processing genres/jazz/jazz.4.au
# Processing genres/jazz/jazz.5.au
# Processing genres/jazz/jazz.6.au
# Processing genres/jazz/jazz.7.au
# Processing genres/jazz/jazz.8.au
# Processing genres/jazz/jazz.9.au
# Processing genres/jazz/jazz.10.au
# Processing genres/jazz/jazz.11.au
# Processing genres/jazz/jazz.12.au
# Processing genres/jazz/jazz.13.au
# Processing genres/jazz/jazz.14.au
# Processing genres/jazz/jazz.15.au
# Processing genres/jazz/jazz.16.au
# Processing genres/jazz/jazz.17.au
# Processing genres/jazz/jazz.18.au
# Processing genres/jazz/jazz.19.au
# Processing genres/jazz/jazz.20.au
# Processing genres/jazz/jazz.21.au
# Processing genres/jazz/jazz.22.au
# Processing genres/jazz/jazz.23.au
# Processing genres/jazz/jazz.24.au
# Processing genres/jazz/jazz.25.au
# Processing genres/jazz/jazz.26.au
# Processing genres/jazz/jazz.27.au
# Processing genres/jazz/jazz.28.au
# Processing genres/jazz/jazz.29.au
# Processing genres/jazz/jazz.30.au
# Processing genres/jazz/jazz.31.au
# Processing genres/jazz/jazz.32.au
# Processing genres/jazz/jazz.33.au
# Processing genres/jazz/jazz.34.au
# Processing genres/jazz/jazz.35.au
# Processing genres/jazz/jazz.36.au
# Processing genres/jazz/jazz.37.au
# Processing genres/jazz/jazz.38.au
# Processing genres/jazz/jazz.39.au
# Processing genres/jazz/jazz.40.au
# Processing genres/jazz/jazz.41.au
# Processing genres/jazz/jazz.42.au
# Processing genres/jazz/jazz.43.au
# Processing genres/jazz/jazz.44.au
# Processing genres/jazz/jazz.45.au
# Processing genres/jazz/jazz.46.au
# Processing genres/jazz/jazz.47.au
# Processing genres/jazz/jazz.48.au
# Processing genres/jazz/jazz.49.au
# Processing genres/jazz/jazz.50.au
# Processing genres/jazz/jazz.51.au
# Processing genres/jazz/jazz.52.au
# Processing genres/jazz/jazz.53.au
# Processing genres/jazz/jazz.54.au
# Processing genres/jazz/jazz.55.au
# Processing genres/jazz/jazz.56.au
# Processing genres/jazz/jazz.57.au
# Processing genres/jazz/jazz.58.au
# Processing genres/jazz/jazz.59.au
# Processing genres/jazz/jazz.60.au
# Processing genres/jazz/jazz.61.au
# Processing genres/jazz/jazz.62.au
# Processing genres/jazz/jazz.63.au
# Processing genres/jazz/jazz.64.au
# Processing genres/jazz/jazz.65.au
# Processing genres/jazz/jazz.66.au
# Processing genres/jazz/jazz.67.au
# Processing genres/jazz/jazz.68.au
# Processing genres/jazz/jazz.69.au
# Processing genres/jazz/jazz.70.au
# Processing genres/jazz/jazz.71.au
# Processing genres/jazz/jazz.72.au
# Processing genres/jazz/jazz.73.au
# Processing genres/jazz/jazz.74.au
# Processing genres/jazz/jazz.75.au
# Processing genres/jazz/jazz.76.au
# Processing genres/jazz/jazz.77.au
# Processing genres/jazz/jazz.78.au
# Processing genres/jazz/jazz.79.au
# Processing genres/jazz/jazz.80.au
# Processing genres/jazz/jazz.81.au
# Processing genres/jazz/jazz.82.au
# Processing genres/jazz/jazz.83.au
# Processing genres/jazz/jazz.84.au
# Processing genres/jazz/jazz.85.au
# Processing genres/jazz/jazz.86.au
# Processing genres/jazz/jazz.87.au
# Processing genres/jazz/jazz.88.au
# Processing genres/jazz/jazz.89.au
# Processing genres/jazz/jazz.90.au
# Processing genres/jazz/jazz.91.au
# Processing genres/jazz/jazz.92.au
# Processing genres/jazz/jazz.93.au
# Processing genres/jazz/jazz.94.au
# Processing genres/jazz/jazz.95.au
# Processing genres/jazz/jazz.96.au
# Processing genres/jazz/jazz.97.au
# Processing genres/jazz/jazz.98.au
# Processing genres/jazz/jazz.99.au
# Processing genres/jazz/jazz.100.au

# %%
all_mfcc_metal = []
for i in range(100):
    print('Processing genres/metal/metal.{}.au'.format(i+1))
    mfcc = get_mfcc('genres/metal/metal.{}.au'.format(i+1))
    all_mfcc_metal.append(mfcc)
# Out:
# Processing genres/metal/metal.1.au
# Processing genres/metal/metal.2.au
# Processing genres/metal/metal.3.au
# Processing genres/metal/metal.4.au
# Processing genres/metal/metal.5.au
# Processing genres/metal/metal.6.au
# Processing genres/metal/metal.7.au
# Processing genres/metal/metal.8.au
# Processing genres/metal/metal.9.au
# Processing genres/metal/metal.10.au
# Processing genres/metal/metal.11.au
# Processing genres/metal/metal.12.au
# Processing genres/metal/metal.13.au
# Processing genres/metal/metal.14.au
# Processing genres/metal/metal.15.au
# Processing genres/metal/metal.16.au
# Processing genres/metal/metal.17.au
# Processing genres/metal/metal.18.au
# Processing genres/metal/metal.19.au
# Processing genres/metal/metal.20.au
# Processing genres/metal/metal.21.au
# Processing genres/metal/metal.22.au
# Processing genres/metal/metal.23.au
# Processing genres/metal/metal.24.au
# Processing genres/metal/metal.25.au
# Processing genres/metal/metal.26.au
# Processing genres/metal/metal.27.au
# Processing genres/metal/metal.28.au
# Processing genres/metal/metal.29.au
# Processing genres/metal/metal.30.au
# Processing genres/metal/metal.31.au
# Processing genres/metal/metal.32.au
# Processing genres/metal/metal.33.au
# Processing genres/metal/metal.34.au
# Processing genres/metal/metal.35.au
# Processing genres/metal/metal.36.au
# Processing genres/metal/metal.37.au
# Processing genres/metal/metal.38.au
# Processing genres/metal/metal.39.au
# Processing genres/metal/metal.40.au
# Processing genres/metal/metal.41.au
# Processing genres/metal/metal.42.au
# Processing genres/metal/metal.43.au
# Processing genres/metal/metal.44.au
# Processing genres/metal/metal.45.au
# Processing genres/metal/metal.46.au
# Processing genres/metal/metal.47.au
# Processing genres/metal/metal.48.au
# Processing genres/metal/metal.49.au
# Processing genres/metal/metal.50.au
# Processing genres/metal/metal.51.au
# Processing genres/metal/metal.52.au
# Processing genres/metal/metal.53.au
# Processing genres/metal/metal.54.au
# Processing genres/metal/metal.55.au
# Processing genres/metal/metal.56.au
# Processing genres/metal/metal.57.au
# Processing genres/metal/metal.58.au
# Processing genres/metal/metal.59.au
# Processing genres/metal/metal.60.au
# Processing genres/metal/metal.61.au
# Processing genres/metal/metal.62.au
# Processing genres/metal/metal.63.au
# Processing genres/metal/metal.64.au
# Processing genres/metal/metal.65.au
# Processing genres/metal/metal.66.au
# Processing genres/metal/metal.67.au
# Processing genres/metal/metal.68.au
# Processing genres/metal/metal.69.au
# Processing genres/metal/metal.70.au
# Processing genres/metal/metal.71.au
# Processing genres/metal/metal.72.au
# Processing genres/metal/metal.73.au
# Processing genres/metal/metal.74.au
# Processing genres/metal/metal.75.au
# Processing genres/metal/metal.76.au
# Processing genres/metal/metal.77.au
# Processing genres/metal/metal.78.au
# Processing genres/metal/metal.79.au
# Processing genres/metal/metal.80.au
# Processing genres/metal/metal.81.au
# Processing genres/metal/metal.82.au
# Processing genres/metal/metal.83.au
# Processing genres/metal/metal.84.au
# Processing genres/metal/metal.85.au
# Processing genres/metal/metal.86.au
# Processing genres/metal/metal.87.au
# Processing genres/metal/metal.88.au
# Processing genres/metal/metal.89.au
# Processing genres/metal/metal.90.au
# Processing genres/metal/metal.91.au
# Processing genres/metal/metal.92.au
# Processing genres/metal/metal.93.au
# Processing genres/metal/metal.94.au
# Processing genres/metal/metal.95.au
# Processing genres/metal/metal.96.au
# Processing genres/metal/metal.97.au
# Processing genres/metal/metal.98.au
# Processing genres/metal/metal.99.au
# Processing genres/metal/metal.100.au

# %%
all_mfcc_pop = []
for i in range(100):
    print('Processing genres/pop/pop.{}.au'.format(i+1))
    mfcc = get_mfcc('genres/pop/pop.{}.au'.format(i+1))
    all_mfcc_pop.append(mfcc)
# Out:
# Processing genres/pop/pop.1.au
# Processing genres/pop/pop.2.au
# Processing genres/pop/pop.3.au
# Processing genres/pop/pop.4.au
# Processing genres/pop/pop.5.au
# Processing genres/pop/pop.6.au
# Processing genres/pop/pop.7.au
# Processing genres/pop/pop.8.au
# Processing genres/pop/pop.9.au
# Processing genres/pop/pop.10.au
# Processing genres/pop/pop.11.au
# Processing genres/pop/pop.12.au
# Processing genres/pop/pop.13.au
# Processing genres/pop/pop.14.au
# Processing genres/pop/pop.15.au
# Processing genres/pop/pop.16.au
# Processing genres/pop/pop.17.au
# Processing genres/pop/pop.18.au
# Processing genres/pop/pop.19.au
# Processing genres/pop/pop.20.au
# Processing genres/pop/pop.21.au
# Processing genres/pop/pop.22.au
# Processing genres/pop/pop.23.au
# Processing genres/pop/pop.24.au
# Processing genres/pop/pop.25.au
# Processing genres/pop/pop.26.au
# Processing genres/pop/pop.27.au
# Processing genres/pop/pop.28.au
# Processing genres/pop/pop.29.au
# Processing genres/pop/pop.30.au
# Processing genres/pop/pop.31.au
# Processing genres/pop/pop.32.au
# Processing genres/pop/pop.33.au
# Processing genres/pop/pop.34.au
# Processing genres/pop/pop.35.au
# Processing genres/pop/pop.36.au
# Processing genres/pop/pop.37.au
# Processing genres/pop/pop.38.au
# Processing genres/pop/pop.39.au
# Processing genres/pop/pop.40.au
# Processing genres/pop/pop.41.au
# Processing genres/pop/pop.42.au
# Processing genres/pop/pop.43.au
# Processing genres/pop/pop.44.au
# Processing genres/pop/pop.45.au
# Processing genres/pop/pop.46.au
# Processing genres/pop/pop.47.au
# Processing genres/pop/pop.48.au
# Processing genres/pop/pop.49.au
# Processing genres/pop/pop.50.au
# Processing genres/pop/pop.51.au
# Processing genres/pop/pop.52.au
# Processing genres/pop/pop.53.au
# Processing genres/pop/pop.54.au
# Processing genres/pop/pop.55.au
# Processing genres/pop/pop.56.au
# Processing genres/pop/pop.57.au
# Processing genres/pop/pop.58.au
# Processing genres/pop/pop.59.au
# Processing genres/pop/pop.60.au
# Processing genres/pop/pop.61.au
# Processing genres/pop/pop.62.au
# Processing genres/pop/pop.63.au
# Processing genres/pop/pop.64.au
# Processing genres/pop/pop.65.au
# Processing genres/pop/pop.66.au
# Processing genres/pop/pop.67.au
# Processing genres/pop/pop.68.au
# Processing genres/pop/pop.69.au
# Processing genres/pop/pop.70.au
# Processing genres/pop/pop.71.au
# Processing genres/pop/pop.72.au
# Processing genres/pop/pop.73.au
# Processing genres/pop/pop.74.au
# Processing genres/pop/pop.75.au
# Processing genres/pop/pop.76.au
# Processing genres/pop/pop.77.au
# Processing genres/pop/pop.78.au
# Processing genres/pop/pop.79.au
# Processing genres/pop/pop.80.au
# Processing genres/pop/pop.81.au
# Processing genres/pop/pop.82.au
# Processing genres/pop/pop.83.au
# Processing genres/pop/pop.84.au
# Processing genres/pop/pop.85.au
# Processing genres/pop/pop.86.au
# Processing genres/pop/pop.87.au
# Processing genres/pop/pop.88.au
# Processing genres/pop/pop.89.au
# Processing genres/pop/pop.90.au
# Processing genres/pop/pop.91.au
# Processing genres/pop/pop.92.au
# Processing genres/pop/pop.93.au
# Processing genres/pop/pop.94.au
# Processing genres/pop/pop.95.au
# Processing genres/pop/pop.96.au
# Processing genres/pop/pop.97.au
# Processing genres/pop/pop.98.au
# Processing genres/pop/pop.99.au
# Processing genres/pop/pop.100.au

# %%
all_mfcc_reggae = []
for i in range(100):
    print('Processing genres/reggae/reggae.{}.au'.format(i+1))
    mfcc = get_mfcc('genres/reggae/reggae.{}.au'.format(i+1))
    all_mfcc_reggae.append(mfcc)
# Out:
# Processing genres/reggae/reggae.1.au
# Processing genres/reggae/reggae.2.au
# Processing genres/reggae/reggae.3.au
# Processing genres/reggae/reggae.4.au
# Processing genres/reggae/reggae.5.au
# Processing genres/reggae/reggae.6.au
# Processing genres/reggae/reggae.7.au
# Processing genres/reggae/reggae.8.au
# Processing genres/reggae/reggae.9.au
# Processing genres/reggae/reggae.10.au
# Processing genres/reggae/reggae.11.au
# Processing genres/reggae/reggae.12.au
# Processing genres/reggae/reggae.13.au
# Processing genres/reggae/reggae.14.au
# Processing genres/reggae/reggae.15.au
# Processing genres/reggae/reggae.16.au
# Processing genres/reggae/reggae.17.au
# Processing genres/reggae/reggae.18.au
# Processing genres/reggae/reggae.19.au
# Processing genres/reggae/reggae.20.au
# Processing genres/reggae/reggae.21.au
# Processing genres/reggae/reggae.22.au
# Processing genres/reggae/reggae.23.au
# Processing genres/reggae/reggae.24.au
# Processing genres/reggae/reggae.25.au
# Processing genres/reggae/reggae.26.au
# Processing genres/reggae/reggae.27.au
# Processing genres/reggae/reggae.28.au
# Processing genres/reggae/reggae.29.au
# Processing genres/reggae/reggae.30.au
# Processing genres/reggae/reggae.31.au
# Processing genres/reggae/reggae.32.au
# Processing genres/reggae/reggae.33.au
# Processing genres/reggae/reggae.34.au
# Processing genres/reggae/reggae.35.au
# Processing genres/reggae/reggae.36.au
# Processing genres/reggae/reggae.37.au
# Processing genres/reggae/reggae.38.au
# Processing genres/reggae/reggae.39.au
# Processing genres/reggae/reggae.40.au
# Processing genres/reggae/reggae.41.au
# Processing genres/reggae/reggae.42.au
# Processing genres/reggae/reggae.43.au
# Processing genres/reggae/reggae.44.au
# Processing genres/reggae/reggae.45.au
# Processing genres/reggae/reggae.46.au
# Processing genres/reggae/reggae.47.au
# Processing genres/reggae/reggae.48.au
# Processing genres/reggae/reggae.49.au
# Processing genres/reggae/reggae.50.au
# Processing genres/reggae/reggae.51.au
# Processing genres/reggae/reggae.52.au
# Processing genres/reggae/reggae.53.au
# Processing genres/reggae/reggae.54.au
# Processing genres/reggae/reggae.55.au
# Processing genres/reggae/reggae.56.au
# Processing genres/reggae/reggae.57.au
# Processing genres/reggae/reggae.58.au
# Processing genres/reggae/reggae.59.au
# Processing genres/reggae/reggae.60.au
# Processing genres/reggae/reggae.61.au
# Processing genres/reggae/reggae.62.au
# Processing genres/reggae/reggae.63.au
# Processing genres/reggae/reggae.64.au
# Processing genres/reggae/reggae.65.au
# Processing genres/reggae/reggae.66.au
# Processing genres/reggae/reggae.67.au
# Processing genres/reggae/reggae.68.au
# Processing genres/reggae/reggae.69.au
# Processing genres/reggae/reggae.70.au
# Processing genres/reggae/reggae.71.au
# Processing genres/reggae/reggae.72.au
# Processing genres/reggae/reggae.73.au
# Processing genres/reggae/reggae.74.au
# Processing genres/reggae/reggae.75.au
# Processing genres/reggae/reggae.76.au
# Processing genres/reggae/reggae.77.au
# Processing genres/reggae/reggae.78.au
# Processing genres/reggae/reggae.79.au
# Processing genres/reggae/reggae.80.au
# Processing genres/reggae/reggae.81.au
# Processing genres/reggae/reggae.82.au
# Processing genres/reggae/reggae.83.au
# Processing genres/reggae/reggae.84.au
# Processing genres/reggae/reggae.85.au
# Processing genres/reggae/reggae.86.au
# Processing genres/reggae/reggae.87.au
# Processing genres/reggae/reggae.88.au
# Processing genres/reggae/reggae.89.au
# Processing genres/reggae/reggae.90.au
# Processing genres/reggae/reggae.91.au
# Processing genres/reggae/reggae.92.au
# Processing genres/reggae/reggae.93.au
# Processing genres/reggae/reggae.94.au
# Processing genres/reggae/reggae.95.au
# Processing genres/reggae/reggae.96.au
# Processing genres/reggae/reggae.97.au
# Processing genres/reggae/reggae.98.au
# Processing genres/reggae/reggae.99.au
# Processing genres/reggae/reggae.100.au

# %%
all_mfcc_rock = []
for i in range(100):
    print('Processing genres/rock/rock.{}.au'.format(i+1))
    mfcc = get_mfcc('genres/rock/rock.{}.au'.format(i+1))
    all_mfcc_rock.append(mfcc)
# Out:
# Processing genres/rock/rock.1.au
# Processing genres/rock/rock.2.au
# Processing genres/rock/rock.3.au
# Processing genres/rock/rock.4.au
# Processing genres/rock/rock.5.au
# Processing genres/rock/rock.6.au
# Processing genres/rock/rock.7.au
# Processing genres/rock/rock.8.au
# Processing genres/rock/rock.9.au
# Processing genres/rock/rock.10.au
# Processing genres/rock/rock.11.au
# Processing genres/rock/rock.12.au
# Processing genres/rock/rock.13.au
# Processing genres/rock/rock.14.au
# Processing genres/rock/rock.15.au
# Processing genres/rock/rock.16.au
# Processing genres/rock/rock.17.au
# Processing genres/rock/rock.18.au
# Processing genres/rock/rock.19.au
# Processing genres/rock/rock.20.au
# Processing genres/rock/rock.21.au
# Processing genres/rock/rock.22.au
# Processing genres/rock/rock.23.au
# Processing genres/rock/rock.24.au
# Processing genres/rock/rock.25.au
# Processing genres/rock/rock.26.au
# Processing genres/rock/rock.27.au
# Processing genres/rock/rock.28.au
# Processing genres/rock/rock.29.au
# Processing genres/rock/rock.30.au
# Processing genres/rock/rock.31.au
# Processing genres/rock/rock.32.au
# Processing genres/rock/rock.33.au
# Processing genres/rock/rock.34.au
# Processing genres/rock/rock.35.au
# Processing genres/rock/rock.36.au
# Processing genres/rock/rock.37.au
# Processing genres/rock/rock.38.au
# Processing genres/rock/rock.39.au
# Processing genres/rock/rock.40.au
# Processing genres/rock/rock.41.au
# Processing genres/rock/rock.42.au
# Processing genres/rock/rock.43.au
# Processing genres/rock/rock.44.au
# Processing genres/rock/rock.45.au
# Processing genres/rock/rock.46.au
# Processing genres/rock/rock.47.au
# Processing genres/rock/rock.48.au
# Processing genres/rock/rock.49.au
# Processing genres/rock/rock.50.au
# Processing genres/rock/rock.51.au
# Processing genres/rock/rock.52.au
# Processing genres/rock/rock.53.au
# Processing genres/rock/rock.54.au
# Processing genres/rock/rock.55.au
# Processing genres/rock/rock.56.au
# Processing genres/rock/rock.57.au
# Processing genres/rock/rock.58.au
# Processing genres/rock/rock.59.au
# Processing genres/rock/rock.60.au
# Processing genres/rock/rock.61.au
# Processing genres/rock/rock.62.au
# Processing genres/rock/rock.63.au
# Processing genres/rock/rock.64.au
# Processing genres/rock/rock.65.au
# Processing genres/rock/rock.66.au
# Processing genres/rock/rock.67.au
# Processing genres/rock/rock.68.au
# Processing genres/rock/rock.69.au
# Processing genres/rock/rock.70.au
# Processing genres/rock/rock.71.au
# Processing genres/rock/rock.72.au
# Processing genres/rock/rock.73.au
# Processing genres/rock/rock.74.au
# Processing genres/rock/rock.75.au
# Processing genres/rock/rock.76.au
# Processing genres/rock/rock.77.au
# Processing genres/rock/rock.78.au
# Processing genres/rock/rock.79.au
# Processing genres/rock/rock.80.au
# Processing genres/rock/rock.81.au
# Processing genres/rock/rock.82.au
# Processing genres/rock/rock.83.au
# Processing genres/rock/rock.84.au
# Processing genres/rock/rock.85.au
# Processing genres/rock/rock.86.au
# Processing genres/rock/rock.87.au
# Processing genres/rock/rock.88.au
# Processing genres/rock/rock.89.au
# Processing genres/rock/rock.90.au
# Processing genres/rock/rock.91.au
# Processing genres/rock/rock.92.au
# Processing genres/rock/rock.93.au
# Processing genres/rock/rock.94.au
# Processing genres/rock/rock.95.au
# Processing genres/rock/rock.96.au
# Processing genres/rock/rock.97.au
# Processing genres/rock/rock.98.au
# Processing genres/rock/rock.99.au
# Processing genres/rock/rock.100.au

# %%
model_blues = hmm.GaussianHMM(n_components=100, n_iter=100, verbose=True)
model_blues.fit(X=np.vstack([mfcc.T for mfcc in all_mfcc_blues]), lengths=[mfcc.shape[1] for mfcc in all_mfcc_blues])
# Out:
#          1   -10367332.4008             +nan
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-157f466e9b4a> in <module>
#       1 model_blues = hmm.GaussianHMM(n_components=100, n_iter=100, verbose=True)
# ----> 2 model_blues.fit(X=np.vstack([mfcc.T for mfcc in all_mfcc_blues]), lengths=[mfcc.shape[1] for mfcc in all_mfcc_blues])
#
# /usr/local/lib/python3.6/dist-packages/hmmlearn/base.py in fit(self, X, lengths)
#     431             for i, j in iter_from_X_lengths(X, lengths):
#     432                 framelogprob = self._compute_log_likelihood(X[i:j])
# --> 433                 logprob, fwdlattice = self._do_forward_pass(framelogprob)
#     434                 curr_logprob += logprob
#     435                 bwdlattice = self._do_backward_pass(framelogprob)
#
# /usr/local/lib/python3.6/dist-packages/hmmlearn/base.py in _do_forward_pass(self, framelogprob)
#     462                        log_mask_zero(self.startprob_),
#     463                        log_mask_zero(self.transmat_),
# --> 464                        framelogprob, fwdlattice)
#     465         with np.errstate(under="ignore"):
#     466             return logsumexp(fwdlattice[-1]), fwdlattice
#
# KeyboardInterrupt:

# %%
model_classical = hmm.GaussianHMM(n_components=100, n_iter=100, verbose=True)
model_classical.fit(X=np.vstack([mfcc.T for mfcc in all_mfcc_classical]), lengths=[mfcc.shape[1] for mfcc in all_mfcc_classical])

# %%
model_country = hmm.GaussianHMM(n_components=100, n_iter=100, verbose=True)
model_country.fit(X=np.vstack([mfcc.T for mfcc in all_mfcc_country]), lengths=[mfcc.shape[1] for mfcc in all_mfcc_country])

# %%
model_disco = hmm.GaussianHMM(n_components=100, n_iter=100, verbose=True)
model_disco.fit(X=np.vstack([mfcc.T for mfcc in all_mfcc_disco]), lengths=[mfcc.shape[1] for mfcc in all_mfcc_disco])

# %%
model_hiphop = hmm.GaussianHMM(n_components=100, n_iter=100, verbose=True)
model_hiphop.fit(X=np.vstack([mfcc.T for mfcc in all_mfcc_hiphop]), lengths=[mfcc.shape[1] for mfcc in all_mfcc_hiphop])

# %%
model_jazz = hmm.GaussianHMM(n_components=100, n_iter=100, verbose=True)
model_jazz.fit(X=np.vstack([mfcc.T for mfcc in all_mfcc_jazz]), lengths=[mfcc.shape[1] for mfcc in all_mfcc_jazz])

# %%
model_metal = hmm.GaussianHMM(n_components=100, n_iter=100, verbose=True)
model_metal.fit(X=np.vstack([mfcc.T for mfcc in all_mfcc_metal]), lengths=[mfcc.shape[1] for mfcc in all_mfcc_metal])

# %%
model_pop = hmm.GaussianHMM(n_components=100, n_iter=100, verbose=True)
model_pop.fit(X=np.vstack([mfcc.T for mfcc in all_mfcc_pop]), lengths=[mfcc.shape[1] for mfcc in all_mfcc_pop])

# %%
model_reggae = hmm.GaussianHMM(n_components=100, n_iter=100, verbose=True)
model_reggae.fit(X=np.vstack([mfcc.T for mfcc in all_mfcc_reggae]), lengths=[mfcc.shape[1] for mfcc in all_mfcc_reggae])

# %%
model_rock = hmm.GaussianHMM(n_components=100, n_iter=100, verbose=True)
model_rock.fit(X=np.vstack([mfcc.T for mfcc in all_mfcc_rock]), lengths=[mfcc.shape[1] for mfcc in all_mfcc_rock])
